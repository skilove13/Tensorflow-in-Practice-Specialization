# %% [markdown]
# <a href="https://colab.research.google.com/github/skilove13/Tensorflow-in-Practice-Specialization/blob/master/Week1_Tensorflow_in_pratice_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#example for y = 2x-1 

import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

model.fit(xs,ys,epochs=1000)

print(model.predict([10.0]))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 31.5646
# Epoch 2/1000
# 1/1 [==============================] - 0s 762us/step - loss: 25.1532
# Epoch 3/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 20.1025
# Epoch 4/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 16.1224
# Epoch 5/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 12.9847
# Epoch 6/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 10.5100
# Epoch 7/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 8.5569
# Epoch 8/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0145
# Epoch 9/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7951
# Epoch 10/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8301
# Epoch 11/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0653
# Epoch 12/1000
# ...
